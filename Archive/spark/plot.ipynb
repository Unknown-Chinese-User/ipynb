# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0,2*np.pi)
plt.plot(np.sin(t),2*np.cos(t))
plt.grid("on")
# plt.daspect([1,0.5])
plt.gca().set_aspect('equal')

plt.show()
