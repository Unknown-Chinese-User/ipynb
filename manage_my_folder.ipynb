# %%
import pandas as pd
import numpy as np
from IPython.display import display
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 5000)
pd.set_option('display.expand_frame_repr', False)

# %%
df=pd.read_excel('./剧本目录.xlsx', index_col=0)

# %%
df
# Out:
#                 剧本名称     人数   类型      背景     难度
# 序号
# 510              小团圆      5  半开放  防疫事迹沉浸    ★★★
# 509          血巫祭杀人魔法      7  半开放      灵异   ★★★★
# 508             飘萍长安      5   开放    本格现代   ★★★★
# 507              西江月      8  半开放      古代    ★★★
# 506           疯狂美食节2      8   开放      欢乐    ★★★
# 505            羽生夜谈2      6  半开放  日风经典延续   ★★★★
# 504             杀人回忆      5   开放    悬疑烧脑   ★★★★
# 503            恶渊百物语      6   开放    灵异微恐   ★★★★
# 502           天使中的魔鬼      5   开放      情感    ★★★
# 501            林深时见鹿      8   开放      欢乐    ★★★
# 500            一楼的尽头      5   开放    悬疑烧脑   ★★★★
# 499               奉养      6   开放      灵异    ★★★
# 498               宿醉      6   开放    都市情感    ★★★
# 497               安生      6   开放      情感    ★★★
# 496              乌托邦      6   开放      架空    ★★★
# 495              普陀峪      7   开放      灵异    ★★★
# 494             棋局黑白      7   开放      警匪    ★★★
# 493             一出好戏      4   开放    悬疑烧脑    ★★★
# ...

# %%
df.sort_values(by="难度")[::-1]
# Out:
#                 剧本名称     人数   类型      背景     难度
# 序号
# 57           死穿白（英文）    NaN   英文     NaN    NaN
# 58         四大名捕2之千门宫      4   开放      武侠    NaN
# 81       帝国旅馆谋杀案（英文）    NaN   英文     NaN    NaN
# 82         好莱坞案件（英文）    NaN   英文     NaN    NaN
# 84         摇滚俱乐部（英文）    NaN   英文     NaN    NaN
# 85          西部惊魂（英文）    NaN   英文     NaN    NaN
# 93         四大名捕1之铁鸡帮      4   开放      武侠    NaN
# 95        四大名捕3之龙门客栈      4   开放      武侠    NaN
# 98          捉妖记西游莲花精      4   开放      架空    NaN
# 99     捉妖相府鱼美人1之爱的信仰      4   开放      架空    NaN
# 100    捉妖相府鱼美人2之妖有妖道      4   开放      架空    NaN
# 248               窥镜      4  半开放      现代    NaN
# 290          吉野家杀人事件      6   封闭      日本    NaN
# 294            魂断太武阁      7  半开放      日本    NaN
# 297               姑娘      6   开放      现代    NaN
# 310             暗至微光      8  半开放     近现代    NaN
# 314                奠      7   封闭      灵异    NaN
# 12              古堡惊魂      8  半开放      魔幻  ★★★★★
# ...

# %%
(393**2-262**2)/2*2680
# Out:
# 114978700.0

# %%
1.  1.14*10^8
2.

# %%
# %pwd
# Out:
# 'E:\\jupyter'

# %%
# %cd ..
# Out:
# E:\

# %%
import glob,os,subprocess,json

cmd=[
        "MediaInfo.exe",
        "--Output=JSON",
        "./yon -.mkv",
    ]

ff=subprocess.run(cmd,shell=True,stdout=subprocess.PIPE,stderr=subprocess.PIPE,text=True)

print("stderr\n"+ff.stderr)
print("stdout\n"+ff.stdout)
# Out:
# stderr
#
# stdout
# {
# "creatingLibrary": {
# "name": "MediaInfoLib",
# "version": "21.09",
# "url": "https://mediaarea.net/MediaInfo"
# },
# "media": {
# "@ref": "./yon -.mkv",
# "track": [
# {
# "@type": "General",
# "UniqueID": "224611685639014014302585872731468404472",
# "VideoCount": "1",
# "AudioCount": "1",
# "FileExtension": "mkv",
# "Format": "Matroska",
# "Format_Version": "4",
# "FileSize": "249631500",
# "Duration": "181.185",
# "OverallBitRate_Mode": "VBR",
# "OverallBitRate": "11022171",
# "FrameRate": "23.976",
# "FrameCount": "4344",
# "StreamSize": "49546",
# "IsStreamable": "Yes",
# "Encoded_Date": "UTC 2021-12-11 22:25:34",
# "File_Created_Date": "UTC 2022-02-06 14:27:45.466",
# "File_Created_Date_Local": "2022-02-06 22:27:45.466",
# "File_Modified_Date": "UTC 2021-12-12 06:30:30.536",
# "File_Modified_Date_Local": "2021-12-12 14:30:30.536",
# "Encoded_Application": "mkvmerge v7.7.0 ('Six Voices') 32bit built on Feb 28 2015 23:23:00",
# ...

# %%
a=2.73/9.8*2
a=65/(6.04-2.96/2)




print(a)
# Out:
# 14.254385964912279

# %%
(14.9-5.8)/6
# Out:
# 1.5166666666666668

# %%
import math
7.62/math.sqrt(2.7)
# Out:
# 4.637384320210407

# %%
4.78*3.15*3600/1610
# Out:
# 33.667826086956524

# %%
12.05*7/2
# Out:
# 42.175000000000004

# %%
(8.1/0.0293)**3*0.00443
# Out:
# 93595.70540496193

# %%
2.64*3.79*0.001*2.44/(5.99*1.65/3.28/3.28)*3.28
# Out:
# 0.08716531976633056

# %%
15.05*math.sqrt(2*40.2/9.81)
# Out:
# 43.08538922333178
